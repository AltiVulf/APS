# %% [markdown]
# <img src="./logo_UNSAM.jpg" align="right" width="150" />
#
# #### Análisis y Procesamiento de Señales
#
# # Trabajo Práctico Semanal Nº1 - TS1
# #### Tomás Altimare Bercovich

# %% [markdown]
# # Resumen
# En este trabajo práctico se realizó un generador de señales senoidales y cuadradas a partir de su parametrización. A partir del mismo, se generaron señales con diferentes parámetros con el fin de graficarlas, analizarlas y compararlas. A su vez, se verificó la ortogonalidad y se graficaron las autocorrelaciones entre las mismas. Por último, se demostró la veracidad de una igualdad trigonométrica planteada. El código fue implementado en Python con Spyder 6

# %% [markdown]
# # Introducción Teórica
# En la teoría de señales se consideran funciones que varían en el tiempo. Para el correcto análisis de las mismas, es esencial definir conceptos como la energía, potencia, ortogonalidad y autocorrelación. A continuación, se presentarán estos conceptos enfocados en señales periódicas (como ondas senoidales y cuadradas) y moduladas.
#
# Una señal x(t) se clasifica como de energía si su energía total es finita. Formalmente se define la energía de la señal como:
# \begin{equation}
# E = \int_{-\infty}^{\infty} |x(t)|^2 dt \tag{1}
# \end{equation}
# y se requiere que:
# \begin{equation}
# 0<E<∞
# \end{equation}
#
# Por otro lado, una señal de potencia posee energía infinita pero una potencia promedio finita. La potencia promedio de x(t) se calcula como:
# \begin{equation}
# P = \lim_{T \to \infty} \frac{1}{T}\int_{-T/2}^{T/2} |x(t)|^2 dt \tag{2}
# \end{equation}
# y para señales de potencia este límite existe y es finito
#
# En la práctica, las señales periódicas continuas típicas (por ejemplo, una onda senoidal o una onda cuadrada infinita) no tienden a cero al infinito, por lo que su energía total diverge y se manejan como señales de potencia con una potencia promedio constante.
#
# La ortogonalidad entre dos señales x(t) e y(t) significa que no comparten energía en común, es decir, su producto interno es cero. Matemáticamente se describe como:
# \begin{equation}
# x(t).y(t) = 0 \tag{3}
# \end{equation}
#
# La función de autocorrelación Rxx(n) mide la semejanza de una señal x(t) con una copia de si misma desplazada en el tiempo k veces. Por otro lado, la correlación cruzada es la autocorrelación entre una señal x(t) y otra señal y(t). La autocorrelación se describe como:
# \begin{equation}
# Rxx(n)=\sum_{k=-∞}^{∞} x(k).x[n+k]   \tag{3}
# \end{equation}
# Siendo que, en el caso de estar utilizando dos señales, x[n+k] es reemplazada por la y(t) en cuestión.
#
# Para este trabajo, son generadas dos tipos de señales periódicas:
# - Senoidales, descriptas como:
# \begin{equation}
# x(t) = Vmax . sen(2 . \pi . \omega . t + \phi ) + dc
# \end{equation}
# - Cuadradas (o de tipo escalón).
#
# Por último, para demostrar la igualdad de la igualdad trigonométrica se utilizarán las siguientes propiedades trigonométricas:
# \begin{equation} cos(α + β) = cos(α).cos(β) + sen(α).sen(β) \tag{4} \end{equation}
# \begin{equation} cos(α - β) = cos(α).cos(β) - sen(α).sen(β) \tag{5} \end{equation}

# %% [markdown]
# # Análisis y Desarrollo
# Se comenzó definiendo 6 señales: 4 señales senoidales y 2 de tipo "escalón". Las mismas se separaron en "Figuras", que van del 1 al 6, siendo las siguientes:
# - Figura 1: Senoidal con frecuencia de 2KHz y amplitud = 1.
# - Figura 2: Senoidal con frecuencia de 2KHz amplitud = 2 y desfasada π/2.
# - Figura 3: Senoidal modulada en amplitud por una señal senoidal de la mitad de su frecuencia.
# - Figura 4: Señal de la figura 4 recortada al 75% de su amplitud.
# - Figura 5: Señal tipo escalón con duty del 50% y frecuencia de 4KHz.
# - Figura 6: Señal tipo escalón con duty del 70% y periodo de 10ms.
#
# Para cada una de estas señales se calculó su potencia, debido a que todas señales planteadas son periódicas.
# Los gráficos de las señales son los siguientes:

# %%
plotear_fig1_a_fig6()

# %% [markdown]
# Como se puede observar en las figuras, la potencia entre la fig.1 a la fig.2, aumenta. Esto se debe a que la fig.2 tiene el doble de amplitud que la fig.1. A su vez, también es notorio a nivel gráfico el desfase entre ambas.
#
# Por otro lado, la figura 3 fue sintetizada a partir de modular la señal de la fig.1 con una señal de la mitad de su frecuencia (1KHz), logrando mostrar una figura similar a la de un seno de 1KHz pero con la amplitud disminuida a la mitad del periodo, sumando así, la información de ambas señales senoidales en una sola.
#
# Por último con relación a las señales senoidales, se recortó potencia de la fig.1 al 75%, mostrando ahora una especie de senoidal que recorta su amplitud (con relación a la fig.1) con un valor constante, tal que su potencia sea del 75% con relación a la de la fig.1. Esto puede notarse tanto gráficamente como numéricamente (a partir del valor de potencia calculado para cada una de las señales).
#
# Por otro lado, se puede notar que las diferentes funciones escalón mantienen una potencia de 1K, siendo que son diferentes señales. Esto se debe a que las mismas mantienen 1 V de valor pico (o amplitud) por cada 10ms, y al ser constantes, la ecuación de potencia se termina simplificando a:
# \begin{equation}
# Potencia = 1/0,001s = 1000
# \end{equation}

# %% [markdown]
# Por otro lado, se verificó la ortogonalidad entre la primer señal y las demás. Esto fue realizado a partir de verificar si, al realizar el producto interno entre los valores de las distintas señales con las de la fig.1, daban cero, llegando a la siguiente tabla:

# %%
plotear_tabla_ortogonalidad()
# Out:
# Figuras a verificar       Resultado  ¿Son ortogonales?
# ---------------------  ------------  -------------------
# Fig 1 vs Fig 2           9.9476e-14  Sí
# Fig 1 vs Fig 3           0           Sí
# Fig 1 vs Fig 4         427.851       No
# Fig 1 vs Fig 5           9.9476e-14  Parecerian serlo
# Fig 1 vs Fig 6         287.322       No

# %% [markdown]
# Al ver gráficamente las fig.1 y fig.2, se podía ver que claramente el resultado daría que son ortogonales. Esto se debe a que la señal 2 prácticamente es igual a la 1, solo que desfasada 90 grados. En cambio, la fig.3 y la fig.5 no parecerían a simple vista ser ortogonales, pero al realizar el producto, se llega a la conclusión de que efectivamente, lo son.
#
# Por último con relación a la ortogonalidad, podemos observar que la fig.4 y 6 no cumplen con ser ortogonales con la fig.1. Esto es esperable, debido a que son funciones bastante diferentes entre sí en lo que respecta a su forma, por lo que hay valores en los cuales, evidentemente, su producto no daría cero.

# %% [markdown]
# Como tercera consigna, fueron graficadas las autocorrelaciones entre la fig.1 con el resto de las figuras, llegando a los siguientes gráficos:

# %%
plotear_fig7_a_fig12()

# %% [markdown]
# En la fig.7 podemos analizar como es que la señal de la fig.1 varía consigo misma. A su vez, las figuras de la 8 a la 12 muestran como varía la fig.1 a partir de las figuras de la 2 a la 6.

# %% [markdown]
# Por otro lado, se propuso demostrar la igualdad de la siguiente propiedad trigonométrica:
# \begin{equation}
# 2*sin(α)*sin(β) = cos(α-β)-cos(α+β)
# \end{equation}
#
# La misma fue verificada a partir de las ecuaciones (4) y (5), siguiendo el siguiente procedimiento:

# %% [markdown]
# <img src="TS1_Resolucion_Punto_3.jpg" align="mid" width="800" />

# %%
plotear_fig13()

# %% [markdown]
# Por último, se buscó verificar numéricamente que la ecuación se cumple si:
# \begin{equation}
# α = ω . t ; β = α/2
# \end{equation}
# Determinando una frecuencia arbitraria de 2KHz (debido a que debería cumplirse para cualquier frecuencia), se calculó el valor del término a la izquierda y derecha de la ecuación a partir de las funciones np.sin y np.cos de la librería numpy, verificando que el valor resultante de su resta, diese un valor cercano a cero (cercano debido a que python a veces realiza redondeos que impiden que resultados que dan 0 analíticamente, den cero (dando numeros muy pequeños, pero no cero). Es decir, se planteó:
# \begin{equation}
# 2.sin(α).sin(β)-cos(α-β)+cos(α+β) = 0
# \end{equation}
# Y dió como resultado que:

# %%
printear_demostracion()
# Out:
# Los términos son iguales, por lo que la igualdad se cumple.

# %% [markdown]
# # Bonus
# Como ejercicio bonus, se procesó y graficó un archivo .wav a partir de la libreria "scipy.io.wavfile", la cual permite leer archivos .wav y devolverte las frecuencias del sonido en el paso del tiempo, concluyendo en el siguiente gráfico:

# %%
plotear_bonus()
# Out:
# C:\Users\Tomas\AppData\Local\Temp\ipykernel_15396\3096446535.py:290: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs_wav, x_wav = waves.read(archivo)

# %% [markdown]
# # Conclusión
# En este trabajo se desarrolló y probó un generador de señales discretas (senoidales y cuadradas) parametrizable, y sobre esa base se analizaron propiedades de potencia, correlación y ortogonalidad. Desde el punto de vista de potencia de la señal, se verificó de manera teórica y analítica que las ondas senoidales y cuadradas periódicas acotadas en tiempo se clasifican como señales de potencia. En relación a la ortogonalidad, se aplicó la definición de que: dos señales muestreadas son ortogonales su producto interno es cercano a cero. Esto quedó corroborado en los casos analizados, y se destacó lenguajes como Python suelen devolver numeros muy chiquitos en vez de "ceros", por lo que se debe estar atento a ello y tomarlo en cuenta.
#
# Por otro lado, también se destacó la importancia de definir correctamente la frecuencia de muestreo suficientemente (Nyquist) y el numero de muestras para evitar perturbaciones (señales "solapadas") o malas representaciones gráficas.

# %% [markdown]
# # Autoevaluación del desarrollo
# Resolví la tarea, pero tengo dudas. Principalmente con los gráficos de autocorrelación: ¿Hay alguna información que se le pueda sacar a parte de la mencionada anteriormente? No termino de entender el objetivo de realizar los gráficos (en términos de información obtenida). Por otro lado, a nivel programación y lenguaje, voy entendiendo todo, eso no me complica. Lo que más me complica viene siendo lo teórico (en general).
#
# Sí, utilicé una IA (chatGPT). Sinceramente prefiero dejarla como herramienta de última mano para cuando algo realmente me está trabando, por lo que la terminé utilizando 2 o 3 veces a lo sumo, pero me sirvió para ver por donde ir encarando algunas consignas. Más que nada, como una herramienta para ayudarme a ver que funciones (de numpy, scipy, etc.) podía llegar a utilizar. No la utilicé para redactar ni interpretar los gráficos ni sacar conclusiones, pero si para reforzar y consultar conceptos teóricos.

# %% [markdown]
# # Bibliografía
# - https://numpy.org/devdocs/reference/generated/numpy.correlate.html
# - https://blog.espol.edu.ec/telg1001/senales-de-energia-y-potencia/
# - https://matplotlib.org/stable/
# - https://www.superprof.es/apuntes/escolar/matematicas/trigonometria/identidades-trigonometricas.html
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.io.wavfile.read.html

# %% [markdown]
# # Apéndice
# ## Código completo:

# %%
"""
Created on Wed Aug 20 2025

@author: Tomás Altimare Bercovich

Descripción:
------------
    En este trabajo práctico se realizó un generador de señales 
senoidales y cuadradas a partir de su parametrización. A partir 
del mismo, se generaron señales con diferentes parámetros con 
el fin de graficarlas, analizarlas y compararlas. A su vez, 
se verificó la ortogonalidad y se graficaron las autocorrelaciones 
entre las mismas. Por último, se demostró la vericidad de una 
igualdad trigonométrica planteada. 

"""

#%% Importo los módulos y bibliotecas que voy a utilizar
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker # Para poder graficar con ejes que tienen valores muy pequeños
import scipy.signal as sig
import scipy.io.wavfile as waves
from tabulate import tabulate

#%% Defino variables del programa
fs = 1000000 # frecuencia de f_wav (Hz)
ts = 1/fs  # Tiempo entre muestras
N = 1000 # cantidad de muestras
T_simulacion = N/fs
amp = 1 # Normalizo la amplitud de las señales en 1

#%% Defino la función para la señal senoidal
def funcion_senoidal(ff, nn, vmax = 1, dc = 0, ph = 0, fs = 2): 
    """
    funcion_senoidal(frec, #_muestras, amplitud, offset, fase, frec_f_wav)
    - Output: tiempo (eje Y), funcion (eje X)
    """    
    # Grilla de sampleo temporal
    n = np.arange(nn)
    tt = n / fs
    
    xx = vmax * np.sin( 2 * np.pi * ff * tt + ph ) + dc
    return tt, xx

#%% Defino la función para la señal cuadrada
def funcion_cuadrada(ff, nn, duty, vmax = 1, dc = 0,ph = 0, fs = 2):
    """
    funcion_cuadrada(frecuencia, #_muestras, duty, amplitud, offset, fase, frec_muestreo)
    - El duty puede ir de 0 a 100
    - Salida: tt (s), xx (amplitud)
    """
    # Grilla de sampleo temporal 
    n = np.arange(nn)
    tt = n / fs
    duty_frac = duty / 100

    # Fase normalizada en [0,1) (construyo la periodicidad de la funcion)
    fase = ( (ff * n / fs) + (ph / (2*np.pi)) ) % 1
    
    # Grafica arriba cuando fase < duty_frac, abajo en el otro caso
    xx = np.where(fase < duty_frac, vmax, -vmax) + dc
    return tt, xx

#%%############
## Punto (1) ##
###############
#%% Armo las funciones que voy a graficar
# Señal 1
t1, x1 = funcion_senoidal (vmax = amp, dc = 0, ff = 2000, ph = 0, nn = N, fs = fs)
# Señal 2
t2, x2 = funcion_senoidal (vmax = 2*amp, dc = 0, ff = 2000, ph = (np.pi/2), nn = N, fs = fs)
# Señal 3
t3, x3 = funcion_senoidal (vmax = amp, dc = 0, ff = 1000, ph = 0, nn = N, fs = fs)
x_modulada = x1 * x3
# Señal 4
recorte = 0.75
x_recortada = np.clip(x1, -amp*recorte, amp*recorte)
potencia_total = (amp**2)/2
potencia_al_75 = (0.75) * potencia_total
# Señal 5
tsq1, xsq1 = funcion_cuadrada(vmax = amp, dc = 0, ff = 4000, duty = 50, ph = 0, nn = N, fs = fs)
# Señal 6
t_rectangulo = 0.001 # duracion de un periodo
ff_rectangulo = 1/t_rectangulo # periodo
tsq2, xsq2 = funcion_cuadrada(vmax = amp, dc = 0, ff = ff_rectangulo, duty = 70, ph = 0, nn = N, fs = fs)

#%% Imprimo los gráficos
def plotear_fig1_a_fig6 ():
    plt.figure(1)
    plt.title('Figura 1: Seno con frec = 2KHz')
    plt.grid(True)
    plt.plot(t1, x1, 'o--', color = 'teal')
    plt.xlim(0, T_simulacion)
    plt.xlabel("Tiempo [s]")
    plt.ylabel("Amplitud")
    # Añado una leyenda con los datos sobre la señal:
    potencia = np.sum(x1 ** 2)/(2*N+1)
    info_fig1 = (
        f"Tiempo entre muestras: {ts} s\n"
        f"Número de muestras: {N}\n"
        f"Potencia: {potencia}"
    )
    plt.figtext(0.5, -0.1, info_fig1, fontsize=12, ha="center", va="center",
                bbox=dict(facecolor="white", alpha=0.7, edgecolor="grey"))
    plt.tight_layout()
    
    plt.figure(2)
    plt.title('Figura 2: Seno con frec = 2KHz desfasada π/2')
    plt.grid(True)
    plt.plot(t2, x2, 'o--', color = 'teal')
    plt.xlim(0, T_simulacion)
    plt.xlabel("Tiempo [s]")
    plt.ylabel("Amplitud")
    potencia = np.sum(x2 ** 2)/(2*N+1)
    info_fig2 = (
        f"Tiempo entre muestras: {ts} s\n"
        f"Número de muestras: {N}\n"
        f"Potencia: {potencia}"
    )
    plt.figtext(0.5, -0.1, info_fig2, fontsize=12, ha="center", va="center",
                bbox=dict(facecolor="white", alpha=0.7, edgecolor="grey"))
    plt.tight_layout()
    
    plt.figure(3)
    plt.title('Figura 3: Seno de 2KHz modulada con Seno de 1KHz')
    plt.grid(True)
    plt.plot(t1, x_modulada, 'o--', color = 'teal')
    plt.xlim(0, T_simulacion)
    plt.xlabel("Tiempo [s]")
    plt.ylabel("Amplitud")
    potencia = np.sum(x_modulada ** 2)/(2*N+1)
    info_fig3 = (
        f"Tiempo entre muestras: {ts} s\n"
        f"Número de muestras: {N}\n"
        f"Potencia: {potencia}"
    )
    plt.figtext(0.5, -0.1, info_fig3, fontsize=12, ha="center", va="center",
                bbox=dict(facecolor="white", alpha=0.7, edgecolor="grey"))
    plt.tight_layout()
    
    plt.figure(4)
    plt.title('Figura 4: Seno de 2KHz recortado al 75%')
    plt.grid(True)
    plt.plot(t1, x_recortada, 'o--', color = 'teal')
    plt.xlim(0, T_simulacion)
    plt.xlabel("Tiempo [s]")
    plt.ylabel("Amplitud")
    potencia = np.sum(x_recortada ** 2)/(2*N+1)
    info_fig4 = (
        f"Tiempo entre muestras: {ts} s\n"
        f"Número de muestras: {N}\n"
        f"Potencia: {potencia}"
    )
    plt.figtext(0.5, -0.1, info_fig4, fontsize=12, ha="center", va="center",
                bbox=dict(facecolor="white", alpha=0.7, edgecolor="grey"))
    plt.tight_layout()
    
    plt.figure(5)
    plt.title('Figura 5: Funcion Cuadrada de 4KHz')
    plt.grid(True)
    plt.plot(tsq1, xsq1, 'o--', color = 'teal')
    plt.xlim(0, T_simulacion)
    plt.xlabel("Tiempo [s]")
    plt.ylabel("Amplitud")
    potencia = np.sum(xsq1 ** 2)
    info_fig5 = (
        f"Tiempo entre muestras: {ts} s\n"
        f"Número de muestras: {N}\n"
        f"Potencia: {potencia}"
    )
    plt.figtext(0.5, -0.1, info_fig5, fontsize=12, ha="center", va="center",
                bbox=dict(facecolor="white", alpha=0.7, edgecolor="grey"))
    plt.tight_layout()
    
    plt.figure(6)
    plt.title('Figura 6: Funcion Cuadrada de 10ms')
    plt.grid(True)
    plt.plot(tsq2, xsq2, 'o--', color = 'teal')
    plt.xlim(0, T_simulacion)
    plt.xlabel("Tiempo [s]")
    plt.ylabel("Amplitud")
    potencia = np.sum(xsq2 ** 2)
    info_fig6 = (
        f"Tiempo entre muestras: {ts} s\n"
        f"Número de muestras: {N}\n"
        f"Potencia: {potencia}"
    )
    plt.figtext(0.5, -0.1, info_fig6, fontsize=12, ha="center", va="center",
                bbox=dict(facecolor="white", alpha=0.7, edgecolor="grey"))
    plt.tight_layout()

#%%############
## Punto (2) ##
###############
#%% Verifico ortogonalidad entre la primera señal y las demás
Xort_12 = np.sum(x1 * x2)
Xort_1_mod = np.sum(x1 * x_modulada)
Xort_1_rec = np.sum(x1 * x_recortada)
Xort_1_sq1 = np.sum(x1 * xsq1)
Xort_1_sq2 = np.sum(x1 * xsq2)

def plotear_tabla_ortogonalidad():
    datos = [["Fig 1 vs Fig 2", Xort_12, "Sí"],
             ["Fig 1 vs Fig 3", Xort_1_mod, "Sí"],
             ["Fig 1 vs Fig 4", Xort_1_rec, "No"],
             ["Fig 1 vs Fig 5", Xort_1_sq1, "Parecerian serlo"],
             ["Fig 1 vs Fig 6", Xort_1_sq2, "No"]]
    print(tabulate(datos, headers=["Figuras a verificar", "Resultado", "¿Son ortogonales?"]))

#%%############
## Punto (3) ##
###############
#%% Grafico la autocorrelación de la primera señal y la correlación entre ésta y las demás.
Xcorr_11 = sig.correlate(x1, x1, mode = 'full')
Xcorr_12 = sig.correlate(x1, x2, mode = 'full')
Xcorr_1_mod = sig.correlate(x1, x_modulada, mode = 'full')
Xcorr_1_rec = sig.correlate(x1, x_recortada, mode = 'full')
Xcorr_1_sq1 = sig.correlate(x1, xsq1, mode = 'full')
Xcorr_1_sq2 = sig.correlate(x1, xsq2, mode = 'full')

eje_centrado = np.arange(-N+1, N) * ts

def plotear_fig7_a_fig12():
    figuras = [
        ("Figura 7: Autocorrelación de la Fig.1 consigo misma", Xcorr_11),
        ("Figura 8: Autocorrelación de la Fig.1 con la Fig.2", Xcorr_12),
        ("Figura 9: Autocorrelación de la Fig.1 con la Fig.3", Xcorr_1_mod),
        ("Figura 10: Autocorrelación de la Fig.1 con la Fig.4", Xcorr_1_rec),
        ("Figura 11: Autocorrelación de la Fig.1 con la Fig.5", Xcorr_1_sq1),
        ("Figura 12: Autocorrelación de la Fig.1 con la Fig.6", Xcorr_1_sq2)
    ]
    
    for i, (titulo, data) in enumerate(figuras, start=7):
        plt.figure(i)
        plt.title(titulo)
        plt.grid(True)
        plt.plot(eje_centrado, data, '.--', color='teal')
        plt.xlim(-T_simulacion, T_simulacion)
        plt.xlabel("Tiempo [s]")
        plt.ylabel("Amplitud")

        # Ajuste del eje X para evitar la superposición de los valores
        ax = plt.gca()
        ax.xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
        ax.ticklabel_format(axis='x', style='sci', scilimits=(-3, 3))  # notación científica
        ax.xaxis.set_major_locator(ticker.MaxNLocator(6))  # máx 6 ticks en X

        plt.tight_layout()

#%%############
## Punto (4) ##
###############
#%% Mostrar que la igualdad se cumple
frec = 2000
# N = 1000 (definido en linea 24)
nn = np.arange(N, dtype=float)
tt = nn / fs

alfa = frec * tt
beta = alfa/2

termino_izq = 2 * np.sin(alfa) * np.sin(beta)
termino_der = np.cos(alfa - beta) * np.cos(alfa + beta)

def printear_demostracion():
    if ((abs(termino_izq-termino_der) < 1e-9).all): # .all sirve para comparar todos los valores del vector con el escalar 1e-9
        print("Los términos son iguales, por lo que la igualdad se cumple.\n")
    else:
        print("Los terminos no son iguales, por lo que la igualdad no se cumple.\n")

def plotear_fig13():
    plt.figure(13)
    plt.title('Figura 13: Demostración de la propiedad trigonométrica')
    plt.grid(True)
    plt.plot(termino_izq, color = 'red')
    plt.plot(termino_der, color = 'blue')
    plt.xlim(0, N)
    plt.xlabel("Tiempo [s]")
    plt.ylabel("Amplitud")
    plt.tight_layout()

#%%############
##   Bonus   ##
###############
def plotear_bonus():
    archivo = 'TS1_Bonus.wav'
    
    fs_wav, x_wav = waves.read(archivo)
    n_wav = len(x_wav)
    ts_wav = 1/fs_wav
    t_wav = np.arange(0, n_wav * ts_wav, ts_wav)
    uncanal = x_wav[:,0]
    t_final_wav = t_wav[-1]
    
    plt.figure(13)
    plt.title('Figura 13: Señal de sonido')
    plt.grid(True)
    plt.plot(t_wav, uncanal, color = 'teal')
    plt.xlim(0, t_final_wav)
    plt.xlabel('Tiempo (s)')
    plt.ylabel('Sonido')
